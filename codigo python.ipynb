# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_diabetes = pd.read_csv('diabetes.csv')
df_diabetes
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df_diabetes.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
df_diabetes['Outcome'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
frecuencia_valores = df_diabetes['Outcome'].value_counts()
frecuencia_valores
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
fig, ax = plt.subplots()
x = df_diabetes['Diabetes_012']
ax.hist(x, color = '#884EA0', bins = 7)
ax.grid(True, alpha = 0.3)
ax.set_title('Histograma de personas con Diabetes')
ax.set_xlabel('Diagnostico')
ax.set_ylabel('Cantidad de Personas')
plt.show()

# %%
fig, ax = plt.subplots()
x = df_diabetes['Glucose']
y = df_diabetes['DiabetesPedigreeFunction']
ax.set_title('Diagnostico vs Colesterol Alto')
ax.set_xlabel('Glucosa')
ax.set_ylabel('Porcentaje Diabetes')
ax.scatter(x, y, color = '#2ECC71')
plt.show()

# %%
df_diabetes['Age'].unique()
# Out:
# array([ 9.,  7., 11., 10.,  8., 13.,  4.,  6.,  2., 12.,  5.,  1.,  3.])

# %%
plt.scatter(df_diabetes['Insulin'],df_diabetes['Glucose'])
plt.xlabel("Nivel de Insulina")
plt.ylabel("Nivel de Glucosa")
plt.show()

# %%
df = df_diabetes.drop(['Pregnancies','BloodPressure','SkinThickness'],axis=1)
df
# Out:
#      Glucose  Insulin   BMI  DiabetesPedigreeFunction  Age  Outcome
# 0        148        0  33.6                     0.627   50        1
# 1         85        0  26.6                     0.351   31        0
# 2        183        0  23.3                     0.672   32        1
# 3         89       94  28.1                     0.167   21        0
# 4        137      168  43.1                     2.288   33        1
# ..       ...      ...   ...                       ...  ...      ...
# 763      101      180  32.9                     0.171   63        0
# 764      122        0  36.8                     0.340   27        0
# 765      121      112  26.2                     0.245   30        0
# 766      126        0  30.1                     0.349   47        1
# 767       93        0  30.4                     0.315   23        0
#
# [768 rows x 6 columns]

# %%
df.corr()
# Out:
#                            Glucose   Insulin       BMI  \
# Glucose                   1.000000  0.331357  0.221071
# Insulin                   0.331357  1.000000  0.197859
# BMI                       0.221071  0.197859  1.000000
# DiabetesPedigreeFunction  0.137337  0.185071  0.140647
# Age                       0.263514 -0.042163  0.036242
# Outcome                   0.466581  0.130548  0.292695
#
#                           DiabetesPedigreeFunction       Age   Outcome
# Glucose                                   0.137337  0.263514  0.466581
# Insulin                                   0.185071 -0.042163  0.130548
# BMI                                       0.140647  0.036242  0.292695
# DiabetesPedigreeFunction                  1.000000  0.033561  0.173844
# Age                                       0.033561  1.000000  0.238356
# Outcome                                   0.173844  0.238356  1.000000

# %%
plt.scatter(df['Insulin'],df['Glucose'])
plt.xlabel("Nivel de Insulina")
plt.ylabel("Nivel de Glucosa")
plt.show()

# %%
# Filtrar el DataFrame para excluir las filas donde 'Insulin' es igual a 0
df_filtrado = df[df['Insulin'] != 0]

# Crear el gráfico de dispersión con el DataFrame filtrado
plt.scatter(df_filtrado['Insulin'], df_filtrado['Glucose'])
plt.xlabel("Nivel de Insulina")
plt.ylabel("Nivel de Glucosa")
plt.show()

# %%
plt.scatter(df_filtrado['Outcome'], df_filtrado['Glucose'])
plt.xlabel("Diagnostico")
plt.ylabel("Nivel de Glucosa")
plt.show()

# %%
import seaborn as sns

# Crear un gráfico de dispersión con colores diferentes para cada valor de 'Outcome'
sns.scatterplot(x='Glucose', y='Outcome', hue='Outcome', data=df, palette={0: 'blue', 1: 'red'})

# Personalizar etiquetas y leyenda
plt.xlabel("Nivel de Glucosa")
plt.ylabel("Outcome")
plt.yticks([0, 1], ['No Diabetes', 'Diabetes'])  # Corrección en las etiquetas del eje y
plt.legend(title='Diabetes', labels=['Diabetes', 'No Diabetes'])

# Mostrar el gráfico
plt.show()

# %%
import seaborn as sns

# Crear un gráfico de violín para visualizar la distribución de 'Glucose' según 'Outcome'
sns.violinplot(x='Outcome', y='Glucose', data=df, palette=['blue', 'red'])

# Personalizar etiquetas
plt.xlabel("Outcome")
plt.ylabel("Nivel de Glucosa")
plt.xticks([0, 1], ['No Diabetes', 'Diabetes'])

# Mostrar el gráfico
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_8792\4224954188.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='Outcome', y='Glucose', data=df, palette=['blue', 'red'])

# %%
matriz = df.corr()
plt.matshow(matriz, cmap="bwr", vmin=-1, vmax = 1)
plt.xticks(range(6), df.columns, rotation = 90)
plt.yticks(range(6), df.columns)

for i in range(len(matriz.columns)):
    for j in range(len(matriz.columns)):
        plt.text(i,j, round(matriz.iloc[i,j],2), ha = "center", va = "center")

plt.colorbar()
plt.show()

# %%
nuevo_orden=['Outcome','Glucose','Insulin','BMI','DiabetesPedigreeFunction','Age']
df = df[nuevo_orden]
df
# Out:
#      Outcome  Glucose  Insulin   BMI  DiabetesPedigreeFunction  Age
# 0          1      148        0  33.6                     0.627   50
# 1          0       85        0  26.6                     0.351   31
# 2          1      183        0  23.3                     0.672   32
# 3          0       89       94  28.1                     0.167   21
# 4          1      137      168  43.1                     2.288   33
# ..       ...      ...      ...   ...                       ...  ...
# 763        0      101      180  32.9                     0.171   63
# 764        0      122        0  36.8                     0.340   27
# 765        0      121      112  26.2                     0.245   30
# 766        1      126        0  30.1                     0.349   47
# 767        0       93        0  30.4                     0.315   23
#
# [768 rows x 6 columns]

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler(with_mean=True, with_std=True)

df_std = scaler.fit_transform(df)

# Convertir el array NumPy de nuevo a DataFrame
df_std = pd.DataFrame(df_std, columns=df.columns)


df_std
# Out:
#       Outcome   Glucose   Insulin       BMI  DiabetesPedigreeFunction  \
# 0    1.365896  0.848324 -0.692891  0.204013                  0.468492
# 1   -0.732120 -1.123396 -0.692891 -0.684422                 -0.365061
# 2    1.365896  1.943724 -0.692891 -1.103255                  0.604397
# 3   -0.732120 -0.998208  0.123302 -0.494043                 -0.920763
# 4    1.365896  0.504055  0.765836  1.409746                  5.484909
# ..        ...       ...       ...       ...                       ...
# 763 -0.732120 -0.622642  0.870031  0.115169                 -0.908682
# 764 -0.732120  0.034598 -0.692891  0.610154                 -0.398282
# 765 -0.732120  0.003301  0.279594 -0.735190                 -0.685193
# 766  1.365896  0.159787 -0.692891 -0.240205                 -0.371101
# 767 -0.732120 -0.873019 -0.692891 -0.202129                 -0.473785
#
#           Age
# 0    1.425995
# 1   -0.190672
# 2   -0.105584
# 3   -1.041549
# 4   -0.020496
# ..        ...
# 763  2.532136
# ...

# %%
np.mean(df_std[:,0])
# Out:
# -9.25185853854297e-18

# %%
np.std(df_std[:,0])
# Out:
# 1.0

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2)

df_pca = pca.fit_transform(df_std)

df_pca = pd.DataFrame(df_pca, columns=["Outcome","Glucose"])

df_pca
# Out:
#       Outcome   Glucose
# 0    1.520533 -1.556501
# 1   -1.661805 -0.197958
# 2    1.239436 -0.898396
# 3   -1.617175  0.641906
# 4    3.379496  2.322944
# ..        ...       ...
# 763  0.059628 -1.356063
# 764 -0.632437  0.174098
# 765 -0.832886  0.084607
# 766  0.662281 -1.691561
# 767 -1.554492  0.314755
#
# [768 rows x 2 columns]

# %%
pca.explained_variance_ratio_
# Out:
# array([0.33680901, 0.18852206, 0.14620504, 0.14108855, 0.11124776,
#        0.07612758])

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize= (5,5))
plt.rcParams["font.family"] = "serif"

x_label = 'Componente 1 ('+str(round(pca.explained_variance_ratio_[0]*100,2))+'%)'
y_label = 'Componente 2 ('+str(round(pca.explained_variance_ratio_[1]*100,2))+'%)'

ax = fig.add_subplot(1,1,1)
ax.set_xlabel(x_label,fontsize = 10)
ax.set_ylabel(y_label,fontsize = 10)
ax.set_title('Componentes Principales', fontsize = 15, fontstyle = 'italic')
ax.set_xlim(-5,6)

ax.scatter(x = df_pca[:,0], y = df_pca[:,1], s = 20)

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
